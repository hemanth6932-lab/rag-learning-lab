# %%
from docx import Document as DocxDocumnet
import os

# %%
from langchain_community.document_loaders import Docx2txtLoader,UnstructuredWordDocumentLoader

# %%
#Method one using the doc2txtloader 

try:
    docx_loader=Docx2txtLoader("data\doc\BICS_User_Stories.docx")
    docs=docx_loader.load()
    print(f"✅ Loaded {len(docs)} document(s)")
    print(f"Content preview: {docs[0].page_content[:200]}...")
    print(f"Metadata: {docs[0].metadata}")
except Exception as e:
    print(f"error:{e}")
# Out:
# ✅ Loaded 1 document(s)
# Content preview: User Story Document
#
# Project: BICS Internship Management System
#
#
# Personas
#
# Applicant (Student): Submits internship application, tracks status via communications.
#
# Mentor (Staff in 'Mentors' group): R...
# Metadata: {'source': 'data\\doc\\BICS_User_Stories.docx'}

# %%
#Method-2 Unstructured doc loader


try:
   unstructured_loader= UnstructuredWordDocumentLoader("data\doc\BICS_User_Stories.docx",mode="elements")
   unstructured_docs=unstructured_loader.load()

   for i,doc in enumerate(unstructured_docs[:3]):
    print(f"\nElement {i+1}:")
    print(f"Type: {doc.metadata.get('category', 'unknown')}")
    print(f"Content: {doc.page_content[:100]}...")

except Exception as e:
    print(f"error:{e}")
# Out:
# Element 1:
# Type: Title
# Content: User Story Document...
#
# Element 2:
# Type: UncategorizedText
# Content: Project: BICS Internship Management System
# ...
#
# Element 3:
# Type: Title
# Content: Personas...

# %%
unstructured_docs
# Out:
# [Document(metadata={'source': 'data\\doc\\BICS_User_Stories.docx', 'category_depth': 0, 'file_directory': 'data\\doc', 'filename': 'BICS_User_Stories.docx', 'last_modified': '2025-08-31T01:19:52', 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'Title', 'element_id': 'bf7de645fa06aa60eddf01d16fd03e3e'}, page_content='User Story Document'),
#  Document(metadata={'source': 'data\\doc\\BICS_User_Stories.docx', 'category_depth': 0, 'file_directory': 'data\\doc', 'filename': 'BICS_User_Stories.docx', 'last_modified': '2025-08-31T01:19:52', 'languages': ['eng'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'parent_id': 'bf7de645fa06aa60eddf01d16fd03e3e', 'category': 'UncategorizedText', 'element_id': '5b455b1eef706d8831838be389c0cf15'}, page_content='Project: BICS Internship Management System\n'),
# ...
